# %%
"""
Downloads the zip / csv files listed on https://s3.amazonaws.com/hubway-data/index.html
"""

import pandas as pd
import requests

ARCHIVE_URL = "https://s3.amazonaws.com/hubway-data/"

# Make the list of filenames and then download them
filenames = []
# From 01-2015 to 04-2018 they look like this: 201804-hubway-tripdata.zip
# From 05-2018 to (present) 07-2019 they look like this: 201805-bluebikes-tripdata.zip, 201907-bluebikes-tripdata.zip
for year in range(2015, 2020):
    for month in range(1, 13):
        filename = "%d%s-hubway-tripdata.zip" % (year, str(month).zfill(2))
        if (year == 2018 and month > 4) or (year > 2018):
            filename = "%d%s-bluebikes-tripdata.zip" % (year, str(month).zfill(2))
        filenames.append(filename)

    
# And then there are these files with other names
filenames += [
    "hubway_Trips_2011.csv",
    "hubway_Trips_2012.csv",
    "hubway_Trips_2013.csv",
    "hubway_Trips_2014_1.csv",
    "hubway_Trips_2014_2.csv",
]

for filename in filenames:
    url = ARCHIVE_URL + filename
    print("Downloading %s" % url)
    resp = requests.get(url)
    if resp.status_code != 200:
        print("%s not found, skipping! (status: %d)" % (filename, resp.status_code))
        continue

    with open("../data/boston-bike/%s" % filename, 'wb') as f:
        f.write(resp.content)
# Out:
# Downloading https://s3.amazonaws.com/hubway-data/201501-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201502-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201503-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201504-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201505-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201506-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201507-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201508-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201509-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201510-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201511-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201512-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201601-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201602-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201603-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201604-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201605-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201606-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201607-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201608-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201609-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201610-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201611-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201612-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201701-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201702-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201703-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201704-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201705-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201706-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201707-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201708-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201709-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201710-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201711-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201712-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201801-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201802-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201803-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201804-hubway-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201805-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201806-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201807-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201808-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201809-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201810-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201811-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201812-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201901-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201902-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201903-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201904-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201905-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201906-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201907-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201908-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201909-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201910-bluebikes-tripdata.zip
# Downloading https://s3.amazonaws.com/hubway-data/201911-bluebikes-tripdata.zip
# 201911-bluebikes-tripdata.zip not found, skipping! (status: 404)
# Downloading https://s3.amazonaws.com/hubway-data/201912-bluebikes-tripdata.zip
# 201912-bluebikes-tripdata.zip not found, skipping! (status: 404)
# Downloading https://s3.amazonaws.com/hubway-data/hubway_Trips_2011.csv
# Downloading https://s3.amazonaws.com/hubway-data/hubway_Trips_2012.csv
# Downloading https://s3.amazonaws.com/hubway-data/hubway_Trips_2013.csv
# Downloading https://s3.amazonaws.com/hubway-data/hubway_Trips_2014_1.csv
# Downloading https://s3.amazonaws.com/hubway-data/hubway_Trips_2014_2.csv
